# %% [markdown]
# <a href="https://colab.research.google.com/github/hardik1408/time-series-forecasting/blob/main/bihar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading the dataset

# %%
import pandas as pd

# Load your dataset ')
data = pd.read_csv('bihar.csv')

# Transpose the dataset to make days as rows and time intervals as columns
data = data.T

# Set the first row as column names
data.columns = data.iloc[0]
data = data[1:]

# Convert the date index to datetime objects
data.index = pd.to_datetime(data.index)

# Resample the data to daily frequency and sum the power consumption for each day
daily_data = data.resample('D').sum()

# Visualize the first few rows of the preprocessed data
daily_data
# Out:
# 4/12/2023   0.06  0.06  0.06   0.06  0.06  0.06  0.06   0.06   0.06  0.06  \
# 2023-04-13  0.06  0.06  0.06   0.06  0.06  0.06  0.06   0.06   0.06  0.06
# 2023-04-14  0.06  0.06  0.06   0.06  0.06  0.06  0.06   0.06   0.06  0.06
# 2023-04-15  0.06  0.06  0.06   0.06  0.06  0.06  0.06   0.06   0.06  0.06
# 2023-04-16  0.13  0.13  0.13   0.13  0.13  0.13  0.13   0.13   0.13  0.13
# 2023-04-17  3.26  4.86  5.44   5.44  5.18  1.41  0.58   0.32   0.32  0.38
# 2023-04-18  0.32  0.32  0.32   1.15  4.10  2.82  4.35   2.50   0.58  0.32
# 2023-04-19  3.26  1.86  2.05   0.77  0.32  0.32  0.32   0.32   0.32  0.32
# 2023-04-20  2.24  2.69  1.02   0.32  0.32  0.32  0.32   0.32   0.32  0.32
# 2023-04-21  3.65  4.54  6.02   3.65  4.54  2.50  2.75   4.67   3.90  3.90
# 2023-04-22  1.73  2.62  3.84   4.03  4.35  3.39  3.26   1.60   1.66  0.64
# 2023-04-23  6.21  3.52  4.03   0.77  0.32  0.32  0.32   0.32   0.32  0.32
# 2023-04-24  1.02  2.05  2.43   2.56  4.29  5.50  5.76   5.76   5.44  2.62
# 2023-04-25  2.05  3.14  2.62   1.86  4.74  5.18  4.80   3.65   3.84  2.56
# 2023-04-26  0.45  0.45  0.45   0.45  0.45  1.22  2.56   1.92   2.56  1.34
# 2023-04-27  5.70  3.52  3.58   1.66  0.90  2.94  5.89   5.63   5.57  1.79
# 2023-04-28  0.38  1.79  1.86   2.05  1.28  0.32  0.51   1.66   1.92  2.05
# 2023-04-29  5.70  4.99  2.94   1.92  1.60  1.98  1.73   0.13   0.45  0.38
# 2023-04-30  4.99  3.14  4.74   1.86  0.32  0.32  0.32   0.32   0.32  0.96
# 2023-05-01  3.90  2.24  0.38   0.32  0.32  1.02  3.07   2.56   3.46  1.73
# 2023-05-02  3.71  3.01  2.62   3.39  3.26  0.77  0.45   0.32   0.32  0.32
# 2023-05-03  3.33  1.86  1.41   0.70  0.77  0.51  0.38   2.18   0.77  4.16
# 2023-05-04  1.09  1.28  1.34   2.75  2.56  1.98  1.86   0.77   1.98  3.46
# 2023-05-05  4.99  6.02  4.35   4.29  3.52  3.07  2.94   3.20   4.16  3.52
# 2023-05-06  4.93  5.12  3.65   2.05  3.97  3.39  4.16   4.16   2.37  2.50
# 2023-05-07  0.38  1.47  2.43   2.43  2.69  1.28  1.28   3.90   4.03  4.42
# 2023-05-08  3.14  5.95  5.89   4.61  4.10  3.20  1.98   2.94   3.97  1.92
# 2023-05-09  8.51  8.51  4.86   6.72  1.60  2.30  3.07   3.65   3.78  2.43
# 2023-05-10  0.70  3.26  2.56   1.28  0.70  0.51  0.45   1.02   1.22  2.56
# 2023-05-18  2.69
# 2023-05-19  3.71
# 2023-05-20  3.01
# 2023-05-21  2.82
# 2023-05-22  5.82
# 2023-05-23  2.50
# 2023-05-24  6.08
# 2023-05-25  5.44
# 2023-05-26  4.42
# 2023-05-27  2.62
# 2023-05-28  4.48
# 2023-05-29  0.77
# 2023-05-30  0.58
# 2023-05-31  1.66
# 2023-06-01  6.98
# 2023-06-02  9.15
# 2023-06-03  6.27
# 2023-06-04  4.16
# 2023-06-05  6.59
# 2023-06-06  4.93
# 2023-06-07  2.24
# 2023-06-08  2.88
# 2023-06-09  3.52
# 2023-06-10  4.61
# 2023-06-11  2.30
#
# [60 rows x 96 columns]

# %%
from matplotlib import pyplot as plt
data['4/17/2023'].plot(kind='line', figsize=(8, 4), title='4/17/2023')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # Model Selection and Training

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# Create and fit the VAR model
model = VAR(daily_data)
model_fit = model.fit()

# Specify the number of steps ahead for forecasting
steps = len(daily_data)  # Forecast for the entire length of the dataset

# Make forecasts
forecasted_values = model_fit.forecast(y=daily_data.values[-model_fit.k_ar:], steps=steps)

forecasted_values
# Out:
# array([[ 2.39868661e+00,  7.07523297e-01, -1.36336837e+00, ...,
#          5.26920812e-01,  7.65756649e-01, -1.04910767e+01],
#        [-4.82648702e+01, -7.73134574e+01, -8.48998181e+01, ...,
#         -6.72633122e+01, -5.60877686e+01, -2.65253002e+01],
#        [ 3.28973437e+01,  4.74655387e+01,  5.50513591e+01, ...,
#         -6.49656465e+00, -8.14628814e+00, -3.79470413e+01],
#        ...,
#        [ 5.28467404e+02,  2.13697008e+02,  8.28905887e+02, ...,
#          6.52697892e+01, -1.65481367e+02,  2.12814614e+02],
#        [ 6.98195606e+02,  1.37799107e+03,  7.64691828e+02, ...,
#          2.42746185e+03,  2.04084061e+03,  5.37340135e+02],
#        [-1.27163875e+03, -1.69102406e+03, -1.61478785e+03, ...,
#         -1.98385817e+03, -1.48724543e+03,  3.04414156e+02]])

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error

mae_scores = {}
for i, column in enumerate(daily_data.columns):
    true_values = daily_data[column].values[-steps:]
    forecasted = forecasted_values[:, i]
    mae = mean_absolute_error(true_values, forecasted)
    mae_scores[column] = mae
    print(f"MAE for {column}: {mae}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f396817141de> in <cell line: 4>()
#       5     true_values = daily_data[column].values[-steps:]
#       6     forecasted = forecasted_values[:, i]
# ----> 7     mae = mean_absolute_error(true_values, forecasted)
#       8     mae_scores[column] = mae
#       9     print(f"MAE for {column}: {mae}")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     194     0.85...
#     195     """
# --> 196     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     197         y_true, y_pred, multioutput
#     198     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     109
#     110     if y_true.shape[1] != y_pred.shape[1]:
# --> 111         raise ValueError(
#     112             "y_true and y_pred have different number of output ({0}!={1})".format(
#     113                 y_true.shape[1], y_pred.shape[1]
#
# ValueError: y_true and y_pred have different number of output (90!=1)

# %% [markdown]
# #  Prediction

# %%
forecast_horizon = 96  # 15 minutes * 96 = 24 hours

# Forecast the next day's power consumption
forecast, stderr, conf_int = arima_result.forecast(steps=forecast_horizon)

# 'forecast' contains the predicted values for the next day in 15-minute intervals
